# %%
#Stock Price Prediction
#Importing all the required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

data = pd.read_csv("../raw_data/WLTW.csv",parse_dates = True)
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-06-10  128.869995  128.940002  126.300003  127.010002  117.667740
# 1  2016-06-13  127.099998  127.650002  125.309998  125.470001  116.240990
# 2  2016-06-14  124.720001  125.699997  123.940002  124.959999  115.768501
# 3  2016-06-15  125.949997  125.949997  123.699997  124.139999  115.008804
# 4  2016-06-16  123.339996  124.870003  122.750000  124.839996  115.657333
#
#    Volume
# 0  548000
# 1  263300
# 2  329300
# 3  378700
# 4  404800

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean    170.151192   171.863577   168.509785   170.245477   164.696498
# std      33.631734    34.190290    33.298020    33.696126    35.938036
# min     113.809998   116.080002   112.760002   113.400002   105.058815
# 25%     147.070000   148.150006   145.802502   147.035000   139.738724
# 50%     160.444999   161.985001   158.835007   160.345001   153.280014
# 75%     197.172493   199.345005   195.215000   197.337505   193.008632
# max     271.869995   271.869995   268.019989   270.070007   269.332672
#
#              Volume
# count  1.258000e+03
# mean   7.554751e+05
# std    4.839229e+05
# min    1.034000e+05
# 25%    4.866000e+05
# 50%    6.480000e+05
# 75%    8.735500e+05
# max    7.654200e+06

# %%
data.shape
# Out:
# (1258, 7)

# %%
sns.pairplot(data)
plt.tight_layout()

# %%
#Since other parameters have linear relationship with close, we are using some linear models fore prediction

X = data.drop(['Adj Close'], axis=1)
y = data['Adj Close']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=False)

Acc = []

# %%
from sklearn.linear_model import LinearRegression

# model training

model_1 = LinearRegression()
model_1.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-b263610f519a> in <module>
#       4
#       5 model_1 = LinearRegression()
# ----> 6 model_1.fit(X_train, y_train)
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     489
#     490         n_jobs_ = self.n_jobs
# --> 491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     492                          y_numeric=True, multi_output=True)
#     493
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     729         raise ValueError("y cannot be None")
#     730
# --> 731     X = check_array(X, accept_sparse=accept_sparse,
#     732                     accept_large_sparse=accept_large_sparse,
#     733                     dtype=dtype, order=order, copy=copy,
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     457         dtypes_orig = np.array(array.dtypes)
#     458         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 459             dtype_orig = np.result_type(*array.dtypes)
#     460
#     461     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# TypeError: invalid type promotion
